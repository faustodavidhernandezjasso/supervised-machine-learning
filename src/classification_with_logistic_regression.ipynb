# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import math

data_set = pd.read_csv("data_set/third_data_set/archive/diabetes2.csv")
data_set.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
X_ = np.array(data_set.drop('Outcome', axis=1))
Y_ = np.array(data_set['Outcome'])
X_train, X_test, y_train, y_test = train_test_split(X_, Y_, test_size=0.2)
print("Length of X_train: " + str(X_train.shape[0]))
print("Length of X_test: " + str(X_test.shape[0]))
print("Length of y_train: " + str(y_train.shape[0]))
print("Length of y_test: " + str(y_test.shape[0]))
# Out:
# Length of X_train: 614
# Length of X_test: 154
# Length of y_train: 614
# Length of y_test: 154

# %%
print("Shape of X_train: " + str(X_train.shape))
# Out:
# Shape of X_train: (614, 8)

# %%
def sigmoid_function(z):
    return (1 / (1 + np.exp(- z)))

def linear_model(X, w, b):
    return np.dot(X, w) + b

def logistic_regression_model(X, w, b):
    return sigmoid_function(linear_model(X, w, b))

def loss(X, w, b, Y):
    # m = X.shape[1]
    # n = Y.shape[0]
    # new_Y = np.tile(Y, m).reshape(m, n).T
    return (- Y) * np.log(logistic_regression_model(X, w, b)) - (1 - Y) * np.log(1 - logistic_regression_model(X, w, b))

def logistic_cost_function(X, w, b, Y):
    m = X.shape[1]
    return (1 / m) * np.sum(loss(X, w, b, Y))

def error(X, w, b, Y):
    m = X.shape[1]
    return logistic_regression_model(X, w, b) - Y

def derivative_of_w(X, w_init, b, Y):
    m = X.shape[1]
    w = np.zeros(m)
    for i in range(m):
        w[i] = np.dot(error(X, w, b, Y), X[:, i])
    return (1 / m) * w

def derivative_of_b(X, w, b, Y):
    m = X.shape[1]
    return (1 / m) * np.sum(error(X, w, b, Y))

def compute_gradient(X, w, b, Y, num_iter, alpha):
    for i in range(num_iter):
        temp_w = derivative_of_w(X, w, b, Y)
        temp_b = derivative_of_b(X, w, b, Y)
        w = w - (alpha * temp_w)
        b = b - (alpha * temp_b)
    return (w, b)

# %%
n = X_train.shape[1]
w_init = np.array([0.0001] * 8)
alpha = 0.0000000001
print(X_train.shape)
print(y_train.shape)
w, b = gradient_descent(X_train, w_init, 0, y_train, 1000000, alpha)

def prediction(X):
    return sigmoid_function(linear_model(X, w, b))
# Out:
# (614, 8)
# (614,)
